# %% [markdown]
# <a href="https://colab.research.google.com/github/nik8839/deep_learning_project/blob/trial_1/Image_classification_simple_neural_network_validation_set_part_2_increasing_more_epochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# importing libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# Reading all images from google drive

# %%
import os
from PIL import Image
import numpy as np
classes = []
data = []
Y = []
image_folder_path = '/content/drive/MyDrive/dataset'  # Change this to the path where your folders are extracted
folders = os.listdir(image_folder_path)
count = 0
for folder in folders:
    classes.append(folder)
    folder_path = os.path.join(image_folder_path, folder)
    if os.path.isdir(folder_path):
        print(f"Reading images from {folder}")
        images = os.listdir(folder_path)
        for image_name in images:
            Y.append(count)
            image_path = os.path.join(folder_path, image_name)
            image = Image.open(image_path)
            image = image.resize((224, 224), resample=Image.LANCZOS).convert('RGB')
            image_array = np.asarray(image)
            data.append(image_array)

        count += 1
# Out:
# Reading images from lightning
# Reading images from rime
# Reading images from glaze
# Reading images from rainbow
# Reading images from hail
# Reading images from frost
# Reading images from sandstorm
# Reading images from rain
# Reading images from snow
# Reading images from fogsmog
# Reading images from dew

# %%
# Convert the data list to a 4D numpy array
data = np.array(data)
# Convert the Y list to a numpy array
Y = np.array(Y)
# Check the shapes of data and Y
print("Shape of data:", data.shape)
print("Shape of Y:", Y.shape)
# Out:
# Shape of data: (6877, 224, 224, 3)
# Shape of Y: (6877,)

# %%
#data=data/255

# %%
#batch.shape
# Out:
# (77, 224, 224, 3)

# %%
data.shape
# Out:
# (6877, 224, 224, 3)

# %% [markdown]
# Converted x vector to be the numpy array

# %%
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets with a specific random seed (random_state)
X_train, X_test, y_train, y_test = train_test_split(data, Y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# %%
y_train
# Out:
# array([2, 2, 1, ..., 6, 0, 8])

# %%
import tensorflow as tf
from tensorflow.keras import layers,models
import keras

# %%
from tensorflow.keras import regularizers
model=keras.Sequential([
      layers.Conv2D(filters=10,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)),
    layers.MaxPool2D((3,3)),
      layers.Conv2D(filters=10,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)),
    layers.MaxPool2D((3,3)),
      layers.Conv2D(filters=10,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)),
    layers.MaxPool2D((3,3)),


      keras.layers.Flatten(),
     #keras.layers.Dense(100,activation='relu'),
    # keras.layers.Dense(50,activation='relu'),
      #keras.layers.Dense(150,activation='relu',kernel_regularizer=regularizers.l1(0.001)),
       #keras.layers.Dense(125,activation='relu',kernel_regularizer=regularizers.l1(0.001)),
       keras.layers.Dense(100,activation='relu',kernel_regularizer=regularizers.l1(0.001)),
     keras.layers.Dense(25,activation='relu',kernel_regularizer=regularizers.l1(0.01)),
    keras.layers.Dense(11,activation='softmax'),
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history=model.fit(X_train,y_train,epochs=30,validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 129/129 [==============================] - 4s 19ms/step - loss: 8.7735 - accuracy: 0.2058 - val_loss: 6.0489 - val_accuracy: 0.3147
# Epoch 2/30
# 129/129 [==============================] - 2s 16ms/step - loss: 5.5065 - accuracy: 0.4233 - val_loss: 5.1520 - val_accuracy: 0.4426
# Epoch 3/30
# 129/129 [==============================] - 2s 16ms/step - loss: 4.6500 - accuracy: 0.5331 - val_loss: 4.4486 - val_accuracy: 0.5305
# Epoch 4/30
# 129/129 [==============================] - 2s 15ms/step - loss: 4.1341 - accuracy: 0.5775 - val_loss: 4.0458 - val_accuracy: 0.5400
# Epoch 5/30
# 129/129 [==============================] - 2s 14ms/step - loss: 3.7187 - accuracy: 0.6293 - val_loss: 3.8026 - val_accuracy: 0.5414
# Epoch 6/30
# 129/129 [==============================] - 2s 15ms/step - loss: 3.4089 - accuracy: 0.6521 - val_loss: 3.5207 - val_accuracy: 0.5821
# Epoch 7/30
# 129/129 [==============================] - 2s 14ms/step - loss: 3.1706 - accuracy: 0.6795 - val_loss: 3.3657 - val_accuracy: 0.5858
# Epoch 8/30
# 129/129 [==============================] - 2s 13ms/step - loss: 2.9868 - accuracy: 0.6897 - val_loss: 3.1951 - val_accuracy: 0.5967
# Epoch 9/30
# 129/129 [==============================] - 2s 15ms/step - loss: 2.7738 - accuracy: 0.7159 - val_loss: 3.0703 - val_accuracy: 0.5974
# Epoch 10/30
# 129/129 [==============================] - 2s 16ms/step - loss: 2.6247 - accuracy: 0.7280 - val_loss: 3.0086 - val_accuracy: 0.5887
# Epoch 11/30
# 129/129 [==============================] - 2s 15ms/step - loss: 2.5063 - accuracy: 0.7309 - val_loss: 2.8574 - val_accuracy: 0.6126
# Epoch 12/30
# 129/129 [==============================] - 2s 14ms/step - loss: 2.3815 - accuracy: 0.7440 - val_loss: 2.8377 - val_accuracy: 0.5923
# Epoch 13/30
# 129/129 [==============================] - 2s 13ms/step - loss: 2.2468 - accuracy: 0.7612 - val_loss: 2.7815 - val_accuracy: 0.6105
# Epoch 14/30
# 129/129 [==============================] - 2s 13ms/step - loss: 2.1798 - accuracy: 0.7615 - val_loss: 2.8489 - val_accuracy: 0.5552
# Epoch 15/30
# 129/129 [==============================] - 2s 13ms/step - loss: 2.0639 - accuracy: 0.7741 - val_loss: 2.6144 - val_accuracy: 0.6032
# Epoch 16/30
# 129/129 [==============================] - 2s 14ms/step - loss: 1.9555 - accuracy: 0.7908 - val_loss: 2.6480 - val_accuracy: 0.5908
# Epoch 17/30
# 129/129 [==============================] - 2s 16ms/step - loss: 1.8729 - accuracy: 0.7988 - val_loss: 2.6422 - val_accuracy: 0.5807
# Epoch 18/30
# 129/129 [==============================] - 2s 16ms/step - loss: 1.8021 - accuracy: 0.8046 - val_loss: 2.5077 - val_accuracy: 0.5945
# Epoch 19/30
# 129/129 [==============================] - 2s 15ms/step - loss: 1.7628 - accuracy: 0.7927 - val_loss: 2.5284 - val_accuracy: 0.5821
# Epoch 20/30
# 129/129 [==============================] - 2s 14ms/step - loss: 1.6500 - accuracy: 0.8276 - val_loss: 2.5455 - val_accuracy: 0.5850
# Epoch 21/30
# 129/129 [==============================] - 2s 14ms/step - loss: 1.6488 - accuracy: 0.8121 - val_loss: 2.4507 - val_accuracy: 0.5923
# Epoch 22/30
# 129/129 [==============================] - 2s 14ms/step - loss: 1.5648 - accuracy: 0.8235 - val_loss: 2.3601 - val_accuracy: 0.6177
# Epoch 23/30
# 129/129 [==============================] - 2s 14ms/step - loss: 1.5108 - accuracy: 0.8359 - val_loss: 2.3150 - val_accuracy: 0.5952
# Epoch 24/30
# 129/129 [==============================] - 2s 15ms/step - loss: 1.5035 - accuracy: 0.8264 - val_loss: 2.3687 - val_accuracy: 0.5945
# Epoch 25/30
# 129/129 [==============================] - 2s 16ms/step - loss: 1.4170 - accuracy: 0.8395 - val_loss: 2.2735 - val_accuracy: 0.6047
# Epoch 26/30
# 129/129 [==============================] - 2s 15ms/step - loss: 1.3882 - accuracy: 0.8342 - val_loss: 2.3105 - val_accuracy: 0.6010
# Epoch 27/30
# 129/129 [==============================] - 2s 14ms/step - loss: 1.3671 - accuracy: 0.8441 - val_loss: 2.3384 - val_accuracy: 0.6017
# Epoch 28/30
# 129/129 [==============================] - 2s 14ms/step - loss: 1.3479 - accuracy: 0.8434 - val_loss: 2.5881 - val_accuracy: 0.5872
# Epoch 29/30
# 129/129 [==============================] - 2s 14ms/step - loss: 1.2486 - accuracy: 0.8628 - val_loss: 2.3387 - val_accuracy: 0.6134
# Epoch 30/30
# 129/129 [==============================] - 2s 13ms/step - loss: 1.1971 - accuracy: 0.8713 - val_loss: 2.3686 - val_accuracy: 0.6025

# %%
import matplotlib.pyplot as plt

#history = model.fit(X_train, y_train, epochs=100)

# Plot training loss
plt.plot(history.history['loss'])
plt.title('Model Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# Plot training accuracy
plt.plot(history.history['accuracy'])
plt.title('Model Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
model.evaluate(X_test,y_test)
# Out:
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3113 - accuracy: 0.6126
# [2.3112668991088867, 0.6126453280448914]

# %%
from sklearn.metrics import confusion_matrix,classification_report
y_pred=model.predict(X_test)
y_pred_classes=[np.argmax(element) for element in y_pred]
print("classification report\n",classification_report(y_test,y_pred_classes))
# Out:
# 43/43 [==============================] - 0s 6ms/step
# classification report
#                precision    recall  f1-score   support
#
#            0       0.78      0.79      0.78        87
#            1       0.73      0.66      0.69       242
#            2       0.47      0.47      0.47       117
#            3       0.56      0.72      0.63        43
#            4       0.62      0.45      0.52       128
#            5       0.43      0.42      0.42       106
#            6       0.71      0.82      0.76       125
#            7       0.50      0.53      0.51       111
#            8       0.32      0.33      0.33       106
#            9       0.74      0.72      0.73       177
#           10       0.67      0.76      0.71       134
#
#     accuracy                           0.61      1376
#    macro avg       0.59      0.61      0.60      1376
# weighted avg       0.61      0.61      0.61      1376

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test, y_pred_classes)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [ele  for ele in classes])

cm_display.plot()
plt.rcParams['font.size'] =7
plt.show()
